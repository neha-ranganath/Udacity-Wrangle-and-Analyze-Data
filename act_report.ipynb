# %% [markdown]
# # Report: Analysis of WeRateDogs Twitter Data
#
# The aim of this project was to wrangle data related to the tweets made by the WeRateDogs Twitter account.
#
# WeRateDogs is a Twitter account that rates people's dogs and these ratings almost always have a denominator of 10. The numerator are almost always greater than 10. 11/10, 12/10, 13/10, for example.
#
# The WeRateDogs Twitter data contains basic information of their tweets. The details extracted from the data incluse each tweet's text, the dog's rating, dog name, and dog "stage" (doggo, floofer, pupper, and puppo). There are about 2000 tweets in this dataset.
#
# Steps involved in this project included:
# 1. Gathering data
# 2. Accessing data
# 3. Cleaning data
# 4. Storing the cleaned data
# 5. Analyzing and visualizing the clean data
#
# The insights gathered from the data are detailed below.

# %% [markdown]
# ### 1. Number of dogs of each dog type

# %% [markdown]
# ``` count=list(df2['dog_type'].value_counts())
# label=list(df2['dog_type'].value_counts().index)
# fig = plt.figure()
# ax = fig.add_axes([0,0,1,1])
# ax.bar(label,count)
# plt.xlabel("Dog Types")
# plt.ylabel("Count")
# ax.set_title("Number of Dogs of Each Type")
# plt.show()```

# %%
from IPython.display import Image 

Image(url= "data:image/png;base64,...", width=500, height=500)
# Out:
# <img src="data:image/png;base64,..." width="500" height="500"/>

# %% [markdown]
# There are about 250 dogs in this that are puppers, followed by doggos, with approximately 70 to 80 doggos. <br>
#
# Floofers are the least common dog type in this twitter archive, and there are less than 50 tweets that mention them. <br>
#
# There are about 15 tweets in the dataset that include multiple dogs.

# %% [markdown]
# ### 2. Favorite count by dog type

# %% [markdown]
# ```counts = df2.groupby(['dog_type']).favorite_count.mean()
# counts.plot(kind='bar')
# plt.ylabel('Favorite Count')
# plt.title('Favorite Count Vs Dog Type');```

# %%
Image(url= "data:image/png;base64,...", width=500, height=500)
# Out:
# <img src="data:image/png;base64,..." width="500" height="500"/>

# %% [markdown]
# Puppos have the highest favorite count in the Twitter data, with an average of 14,000, followef by floofers, with an average favorite count of a little over 10, 000.

# %% [markdown]
# ### 3. Count of tweets by img_num value

# %% [markdown]
# ```img_count = df2['img_num'].value_counts()
# img_count.plot(kind='bar')
# plt.xlabel('Image Number (1,2,3,4)')
# plt.ylabel('Count')
# plt.title('Count of image no.');```

# %%
Image(url= "data:image/png;base64,...", width=500, height=500)
# Out:
# <img src="data:image/png;base64,..." width="500" height="500"/>

# %% [markdown]
# This bar plot shows that most tweets in the archive have about 1 image per tweet. There are about 1750 such tweets.

# %% [markdown]
# ## Insights:
#
# In this dataset of about 2000 tweets, the following insights were obtained after the data was wrangled and cleaned.
#
# 1. The most frequently occurring dog type in the dataset is pupper, with over 250 tweets, followed by doggo, with a little less than 100 tweets.
#
# 2. There are some tweets in this data with multiple dogs, so their dog type is listed as "multiple". There are approximately 15 such tweets in this dataset.
#
# 3. Floofers and puppos have the highest favorite count in the cleaned dataset. Puppos have the highest favorite count with over 14,000.
#
# 4. Despite the low occurrence of floofers in the Twitter data, they have the second highest favorite count. This suggests that floofers are very popular with users.
#
# 5. img_num value 1.0 is the most commonly occuring value with about 1750 tweets.

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'act_report.ipynb'])
# Out:
# 0
